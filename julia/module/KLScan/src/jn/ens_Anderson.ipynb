# %%
using MFAScan.EnsembleTest
using Random
using LatticeModels
using Plots
using Lattices
using LinearAlgebra
using ProfileView
plotly()
# Out:
# Plots.PlotlyBackend()

# %%
struct CubicParams
    L::Int
    W::Float64
end

# %%
function f(p::CubicParams; rng = Random.GLOBAL_RNG)
    H = cubic(L = p.L, M = p.L, N = p.L) .+ p.W*Diagonal(rand(L*L*L) .- 0.5)
end

function g(p::CubicParams; rng = Random.GLOBAL_RNG)
    H = square(M = p.L, N = p.L) .+ p.W*Diagonal(rand(L*L) .- 0.5)
end

function h(p::CubicParams; rng = Random.GLOBAL_RNG) #Aubry Andre
    H = chain(N = p.L) .+ p.W*Diagonal(cos.(2π*(1:L)*(1 + √5)/2 .+ 2*pi*rand(rng)))
end
# Out:
# h (generic function with 1 method)

# %%
L = 14; W = 3.5; E_c = 0.; E_del = 0.3
l = [2]
q = collect(0:0.3:3)

p = CubicParams(L, W)
ltc = Lattice3D(L, L, L, 1)
# Out:
# Lattice3D{Int64}(14, 14, 14, 1)

# %%
@code_warntype scan_ταf(f, p, E_c, E_del, ltc, l=l, q=q, R=10, nev = 100, seed = rand(1:19999))
# Out:
# MethodInstance for (::MFAScan.EnsembleTest.var"#scan_ταf##kw")(::NamedTuple{(:l, :q, :R, :nev, :seed), Tuple{Vector{Int64}, Vector{Float64}, Int64, Int64, Int64}}, ::typeof(scan_ταf), ::typeof(f), ::CubicParams, ::Float64, ::Float64, ::Lattice3D{Int64})
#   from (::MFAScan.EnsembleTest.var"#scan_ταf##kw")(::Any, ::typeof(scan_ταf), f::Function, params, E_c, E_del, ltc::Lattice) in MFAScan.EnsembleTest at /Users/kimyeongjun/codes/project/julia/module/MFAScan/src/ensemble_test.jl:35
# Arguments
#   _::Core.Const(MFAScan.EnsembleTest.var"#scan_ταf##kw"())
#   @_2::NamedTuple{(:l, :q, :R, :nev, :seed), Tuple{Vector{Int64}, Vector{Float64}, Int64, Int64, Int64}}
#   @_3::Core.Const(MFAScan.EnsembleTest.scan_ταf)
#   f::Core.Const(f)
#   params::CubicParams
#   E_c::Float64
#   E_del::Float64
#   ltc::Lattice3D{Int64}
# Locals
#   c::Float64
#   seed::Int64
#   isherm::Bool
#   l::Vector{Int64}
#   q::Vector{Float64}
#   R::Int64
#   nev::Int64
#   @_16::Float64
#   @_17::Int64
#   @_18::Bool
#   @_19::Vector{Int64}
#   @_20::Vector{Float64}
#   @_21::Int64
#   @_22::Int64
# Body::NTuple{6, Any}
# 1 ── %1  = Base.haskey(@_2, :c)::Core.Const(false)
# └───       goto #3 if not %1
# 2 ──       Core.Const(:(@_16 = Base.getindex(@_2, :c)))
# └───       Core.Const(:(goto %6))
# 3 ┄─       (@_16 = 1.0)
# │    %6  = @_16::Core.Const(1.0)
# │          (c = %6)
# │    %8  = Base.haskey(@_2, :seed)::Core.Const(true)
# │          Core.typeassert(%8, Core.Bool)
# │    %10 = Base.getindex(@_2, :seed)::Int64
# │    %11 = (%10 isa MFAScan.EnsembleTest.Int)::Core.Const(true)
# │          Core.typeassert(%11, Core.Bool)
# └───       goto #5
# 4 ──       Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :seed, MFAScan.EnsembleTest.Int, %10)))
# └───       Core.Const(:(Core.throw(%14)))
# 5 ┄─       (@_17 = %10)
# └───       goto #7
# 6 ──       Core.Const(:(@_17 = 1234))
# 7 ┄─ %19 = @_17::Int64
# │          (seed = %19)
# │    %21 = Base.haskey(@_2, :isherm)::Core.Const(false)
# └───       goto #9 if not %21
# 8 ──       Core.Const(:(Base.getindex(@_2, :isherm)))
# │          Core.Const(:(%23 isa MFAScan.EnsembleTest.Bool))
# │          Core.Const(:(Core.typeassert(%24, Core.Bool)))
# │          Core.Const(:(goto %29))
# │          Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :isherm, MFAScan.EnsembleTest.Bool, %23)))
# │          Core.Const(:(Core.throw(%27)))
# │          Core.Const(:(@_18 = %23))
# └───       Core.Const(:(goto %32))
# 9 ┄─       (@_18 = true)
# │    %32 = @_18::Core.Const(true)
# │          (isherm = %32)
# │    %34 = Base.haskey(@_2, :l)::Core.Const(true)
# │          Core.typeassert(%34, Core.Bool)
# │    %36 = Base.getindex(@_2, :l)::Vector{Int64}
# │    %37 = Core.apply_type(MFAScan.EnsembleTest.Vector, MFAScan.EnsembleTest.Int)::Core.Const(Vector{Int64})
# │    %38 = (%36 isa %37)::Core.Const(true)
# │          Core.typeassert(%38, Core.Bool)
# └───       goto #11
# 10 ─       Core.Const(:(Core.apply_type(MFAScan.EnsembleTest.Vector, MFAScan.EnsembleTest.Int)))
# │          Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :l, %41, %36)))
# └───       Core.Const(:(Core.throw(%42)))
# 11 ┄       (@_19 = %36)
# └───       goto #13
# 12 ─       Core.Const(:(@_19 = Base.vect(1)))
# 13 ┄ %47 = @_19::Vector{Int64}
# │          (l = %47)
# │    %49 = Base.haskey(@_2, :q)::Core.Const(true)
# │          Core.typeassert(%49, Core.Bool)
# │    %51 = Base.getindex(@_2, :q)::Vector{Float64}
# │    %52 = Core.apply_type(MFAScan.EnsembleTest.Vector, MFAScan.EnsembleTest.Float64)::Core.Const(Vector{Float64})
# │    %53 = (%51 isa %52)::Core.Const(true)
# │          Core.typeassert(%53, Core.Bool)
# └───       goto #15
# 14 ─       Core.Const(:(Core.apply_type(MFAScan.EnsembleTest.Vector, MFAScan.EnsembleTest.Float64)))
# │          Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :q, %56, %51)))
# └───       Core.Const(:(Core.throw(%57)))
# 15 ┄       (@_20 = %51)
# └───       goto #17
# 16 ─       Core.Const(:(@_20 = Base.vect(2.0)))
# 17 ┄ %62 = @_20::Vector{Float64}
# │          (q = %62)
# │    %64 = Base.haskey(@_2, :R)::Core.Const(true)
# │          Core.typeassert(%64, Core.Bool)
# │    %66 = Base.getindex(@_2, :R)::Int64
# │    %67 = (%66 isa MFAScan.EnsembleTest.Int)::Core.Const(true)
# │          Core.typeassert(%67, Core.Bool)
# └───       goto #19
# 18 ─       Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :R, MFAScan.EnsembleTest.Int, %66)))
# └───       Core.Const(:(Core.throw(%70)))
# 19 ┄       (@_21 = %66)
# └───       goto #21
# 20 ─       Core.Const(:(@_21 = 10))
# 21 ┄ %75 = @_21::Int64
# │          (R = %75)
# │    %77 = Base.haskey(@_2, :nev)::Core.Const(true)
# │          Core.typeassert(%77, Core.Bool)
# │    %79 = Base.getindex(@_2, :nev)::Int64
# │    %80 = (%79 isa MFAScan.EnsembleTest.Int)::Core.Const(true)
# │          Core.typeassert(%80, Core.Bool)
# └───       goto #23
# 22 ─       Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :nev, MFAScan.EnsembleTest.Int, %79)))
# └───       Core.Const(:(Core.throw(%83)))
# 23 ┄       (@_22 = %79)
# └───       goto #25
# 24 ─       Core.Const(:(@_22 = 10))
# 25 ┄ %88 = @_22::Int64
# │          (nev = %88)
# │    %90 = (:c, :seed, :isherm, :l, :q, :R, :nev)::Core.Const((:c, :seed, :isherm, :l, :q, :R, :nev))
# │    %91 = Core.apply_type(Core.NamedTuple, %90)::Core.Const(NamedTuple{(:c, :seed, :isherm, :l, :q, :R, :nev)})
# │    %92 = Base.structdiff(@_2, %91)::Core.Const(NamedTuple())
# │    %93 = Base.pairs(%92)::Core.Const(Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}())
# │    %94 = Base.isempty(%93)::Core.Const(true)
# │          Core.typeassert(%94, Core.Bool)
# └───       goto #27
# 26 ─       Core.Const(:(Base.kwerr(@_2, @_3, f, params, E_c, E_del, ltc)))
# 27 ┄ %98 = MFAScan.EnsembleTest.:(var"#scan_ταf#5")(c::Core.Const(1.0), seed, isherm::Core.Const(true), l, q, R, nev, @_3, f, params, E_c, E_del, ltc)::NTuple{6, Any}
# └───       return %98

# %%
E, gipr, μqlnμ, τ, α, f_α = scan_ταf(f, p, E_c, E_del, ltc, l=l, q=q, R=10, nev = 100, seed = rand(1:19999))
# Out:
# (-0.00029022182918112395, [343.0; 57.391825139032875; … ; 9.670642128450425e-5; 2.0401532155690394e-5;;], [-2063.2565082807578; -338.8897219118231; … ; -0.0005049366045783743; -0.0001051276026822911;;], [-2.9999999999999996; -2.0812378598099466; … ; 4.750389301383844; 5.550050992594059;;], [3.0912655961780793; 3.0344890742668995; … ; 2.6832353079351887; 2.648080562942746;;], [2.9999999999999996; 2.9915845820900167; … ; 2.4943460300411653; 2.394190696234179;;])

# %%
typeof(f_α)
# Out:
# Matrix{Float64} (alias for Array{Float64, 2})

# %%
plot(log.(l./L), log.(gipr'), label = q', line=:dash, marker = :circle)
# Out:
#     <div id="fb9f0e1b-d12e-4bf6-8497-4407c11fbf9b" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('fb9f0e1b-d12e-4bf6-8497-4407c11fbf9b', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "0.0",
#         "zmin": null,
#         "legendgroup": "0.0",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             4.8283137373023015
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "0.3",
#         "zmin": null,
#         "legendgroup": "0.3",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(227, 111, 71, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(227, 111, 71, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             3.3437064483341
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "0.6",
#         "zmin": null,
#         "legendgroup": "0.6",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(62, 164, 78, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(62, 164, 78, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             1.8909783229921755
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "0.9",
#         "zmin": null,
#         "legendgroup": "0.9",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(195, 113, 210, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(195, 113, 210, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             0.4680225750752355
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "1.2",
#         "zmin": null,
#         "legendgroup": "1.2",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(172, 142, 24, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(172, 142, 24, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             -0.9269724621896408
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "1.5",
#         "zmin": null,
#         "legendgroup": "1.5",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 170, 174, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 170, 174, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             -2.295597700196051
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "1.8",
#         "zmin": null,
#         "legendgroup": "1.8",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(237, 94, 147, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(237, 94, 147, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             -3.6392773180517803
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "2.1",
#         "zmin": null,
#         "legendgroup": "2.1",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(198, 130, 37, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(198, 130, 37, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             -4.959308528728214
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "2.4",
#         "zmin": null,
#         "legendgroup": "2.4",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 169, 141, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 169, 141, 1.000)",
#             "shape": "linear",
#             "dash": "dash",
#             "width": 1
#         },
#         "y": [
#             -6.256890254471731
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             -1.6094379124341003
#         ],
#         "showlegend": true,
#         "mode": "lines+markers",
#         "name": "2.7",
#         "zmin": null,

# %%
p1 = plot(q, τ, legend = false)
p2 = plot(q, α, legend = false)
p3 = plot(α, f_α)
p4 = plot(p1, p2, p3)
# Out:
#     <div id="92002f03-f78f-476e-9753-0c8f912bf505" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('92002f03-f78f-476e-9753-0c8f912bf505', [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             0.0,
#             0.3,
#             0.6,
#             0.9,
#             1.2,
#             1.5,
#             1.8,
#             2.1,
#             2.4,
#             2.7,
#             3.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             -3.0000000000000004,
#             -2.07756162726222,
#             -1.174930892569988,
#             -0.29079877605679244,
#             0.5759603741331627,
#             1.4263350468265086,
#             2.2612101342559825,
#             3.08139164015827,
#             3.8876244968088662,
#             4.680604638682671,
#             5.4609862731878485
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x2",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y2",
#         "x": [
#             0.0,
#             0.3,
#             0.6,
#             0.9,
#             1.2,
#             1.5,
#             1.8,
#             2.1,
#             2.4,
#             2.7,
#             3.0
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             3.1094554725213617,
#             3.0409941018601687,
#             2.9772677967409056,
#             2.917569161787632,
#             2.8613724965843677,
#             2.808282236476418,
#             2.7579984780524978,
#             2.7102914155566524,
#             2.664980529905589,
#             2.6219170129552256,
#             2.580969387339151
#         ],
#         "type": "scatter"
#     },
#     {
#         "xaxis": "x3",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y3",
#         "x": [
#             3.1094554725213617,
#             3.0409941018601687,
#             2.9772677967409056,
#             2.917569161787632,
#             2.8613724965843677,
#             2.808282236476418,
#             2.7579984780524978,
#             2.7102914155566524,
#             2.664980529905589,
#             2.6219170129552256,
#             2.580969387339151
#         ],
#         "showlegend": true,
#         "mode": "lines",
#         "name": "y1",
#         "zmin": null,
#         "legendgroup": "y1",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             3.0000000000000004,
#             2.989859857820271,
#             2.9612915706145313,
#             2.9166110216656613,
#             2.857686621768078,
#             2.786088307888118,
#             2.7031871262385136,
#             2.6102203325107003,
#             2.5083287749645478,
#             2.3985712962964385,
#             2.281921888829605
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "xaxis1": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             0.0,
#             1.0,
#             2.0,
#             3.0
#         ],
#         "range": [
#             -0.09,
#             3.09
#         ],
#         "domain": [
#             0.05100612423447069,
#             0.4934383202099738
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "0",
#             "1",
#             "2",
#             "3"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "y1",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "yaxis3": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             2.4000000000000004,
#             2.6,
#             2.8000000000000003,
#             3.0
#         ],
#         "range": [
#             2.260379545494493,
#             3.0215423433351125
#         ],
#         "domain": [
#             0.03762029746281716,
#             0.4901574803149606
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "2.4",
#             "2.6",
#             "2.8",
#             "3.0"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x3",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "height": 400,
#     "yaxis2": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             2.6,
#             2.7,
#             2.8000000000000003,
#             2.9000000000000004,
#             3.0,
#             3.1
#         ],
#         "range": [
#             2.565114804783685,
#             3.125310055076828
#         ],
#         "domain": [
#             0.5376202974628171,
#             0.9901574803149606
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "2.6",
#             "2.7",
#             "2.8",
#             "2.9",
#             "3.0",
#             "3.1"
#         ],
#         "zeroline": false,
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "anchor": "x2",
#         "visible": true,
#         "ticks": "inside",
#         "tickmode": "array",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "title": "",
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "tickcolor": "rgb(0, 0, 0)",
#         "type": "-"
#     },
#     "xaxis3": {
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "tickvals": [
#             2.6,
#             2.7,
#             2.8000000000000003,
#             2.9000000000000004,
#             3.0,
#             3.1
#         ],
#         "range": [
#             2.565114804783685,
#             3.125310055076828
#         ],
#         "domain": [
#             0.05100612423447069,
#             0.4934383202099738
#         ],
#         "mirror": false,
#         "tickangle": 0,
#         "showline": true,
#         "ticktext": [
#             "2.6",
#             "2.7",
#             "2.8",
#             "2.9

# %%
gipr
# Out:
# 11×1 Matrix{Float64}:
#  125.0
#   28.323913514060518
#    6.625847730402139
#    1.5968334509154483
#    0.3957500467109193
#    0.10070118615848596
#    0.02627132291781746
#    0.007017778747653691
#    0.001917198535656748
#    0.0005350541728072621
#    0.00015238225669878626
