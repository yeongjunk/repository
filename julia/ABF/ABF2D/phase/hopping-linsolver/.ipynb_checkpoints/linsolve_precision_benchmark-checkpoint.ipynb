# %%
using Plots
using BandedMatrices
include("./phase.jl")
# Out:
# ham_sf_pbc (generic function with 1 method)

# %%
L = 1001

H = ham_sf_obc(L = L, rng = MersenneTwister())
H = BandedMatrix(H, (2, 2));

# %%
@time vals, vecs = eigen(Hermitian(Matrix(H)), L÷2+1:L÷2+1);
# Out:
#   0.242091 seconds (118.03 k allocations: 52.804 MiB, 3.04% gc time, 15.50% compilation time)

# %%
plot((abs.(vecs[:, 1])), label = "ψ at E = 0")
xlabel!("sites")
ylabel!("ψ")

# %%
plot(log.(abs.(vecs[:, 1])), label = "ψ at E = 0")
xlabel!("sites")
ylabel!("log(ψ)")

# %%
@time begin
    Y = Array(@view H[:, 1])
    A = H[:, 2:end]
    X = A\Y
end
# Out:
#   0.000138 seconds (21 allocations: 298.391 KiB)
# 1000-element Vector{ComplexF64}:
#      -0.5484622006119343 + 2.310574851489441e-15im
#       0.5919871729255236 - 1.0758654866302226e-15im
#      -0.3973886176889878 + 2.6724969149456208e-15im
#     0.002560236159333049 - 1.3235830437364824e-15im
#   -0.0004462520137559054 - 6.8356111281243274e-15im
#     -0.03687906700288903 + 2.4133516368550133e-15im
#      0.05306040607526559 + 8.054744227663898e-15im
#    -0.009811775503430433 + 2.971128494570682e-14im
#     0.002320725389241594 + 2.8553001632116516e-15im
#      0.33014715395666044 + 4.452496628879136e-15im
#       0.2810681765965415 + 9.618883239419837e-15im
#      -0.2813419836138246 - 8.581316181020879e-15im
#     -0.07611998814184166 - 8.441354609515884e-15im
#                          ⋮
#  -1.3436547681956954e-15 - 8.476105094383834e-23im
#   1.0614175187763953e-15 + 6.691867019865854e-23im
#   -9.845893768474719e-17 - 6.273855157170244e-24im
#   1.3401838158357058e-15 + 8.449214778118574e-23im
#   -2.943163629910686e-15 - 1.8557664342140516e-22im
#    5.641004568807809e-15 + 3.5567109770803615e-22im
#    5.848329239705943e-16 + 3.688030111303109e-23im
#   2.0853063210038383e-14 + 1.3148020789650217e-21im
#    2.237159266756259e-14 + 1.4105473103356244e-21im
#    -9.04389405055047e-15 - 5.702240536578582e-22im
#  -2.0039809980292765e-15 - 1.26352607129243e-22im
#   5.7452321642072114e-15 + 3.622417305107285e-22im

# %%
pushfirst!(X, 1)
X.= X*vecs[1, 1]
# Out:
# 1001-element Vector{ComplexF64}:
#  -0.00032839753149376476 - 9.576247612303398e-8im
#   0.00018011363279859722 + 5.252209838972824e-8im
#   -0.0001944071262647144 - 5.6690157512069534e-8im
#   0.00013050144109278303 + 3.805491801212954e-8im
#    -8.407752347660504e-7 - 2.4517455364279795e-10im
#    1.4654805974156022e-7 + 4.273420005695354e-11im
#     1.211099456754191e-5 + 3.5316307725113928e-9im
#    -1.742490637517398e-5 - 5.0811958725062665e-9im
#    3.2221628548975483e-6 + 9.395999076147138e-10im
#    -7.621204891018455e-7 - 2.2223841061304043e-10im
#   -0.0001084195103890592 - 3.1615708949324513e-8im
#    -9.230209537575777e-5 - 2.691578455342982e-8im
#     9.239201292433922e-5 + 2.6942004991043982e-8im
#                          ⋮
#    4.412529090471762e-19 + 1.2869954297683782e-22im
#  -3.4856689304399664e-19 - 1.0166594572449861e-22im
#   3.2333672088568586e-20 + 9.430731987681457e-24im
#   -4.401130568602488e-19 - 1.283670676772053e-22im
#    9.665276708271261e-19 + 2.819055797471066e-22im
#  -1.8524919755074732e-18 - 5.403133668408943e-22im
#  -1.9205768856469204e-19 - 5.601716031754445e-23im
#   -6.848094482134138e-18 - 1.997372745500554e-21im
#   -7.346775807476485e-18 - 2.142822328916474e-21im
#   2.9699924812373137e-18 + 8.66252948246708e-22im
#    6.581024129011256e-19 + 1.9194767635907145e-22im
#  -1.8867200605495388e-18 - 5.502966172362837e-22im

# %%
plot(log10.(abs.(X)), label = "Linear solve")
plot!(log10.(abs.(vecs[:, 1])), label = "EV algorithm")
xlabel!("sites")
ylabel!("log(ψ)")

# %%
plot(abs.(X), label = "Linear solve")
plot!(abs.(vecs[:, 1]), label = "EV algorithm")
xlabel!("sites")
ylabel!("ψ")
